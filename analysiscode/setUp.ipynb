# %%
import os
import glob

# %%
#systems = glob.glob("../4_Equilibration/alphafold_narval/systems/*t5a*/")
#for i in range(len(systems)):
#    os.mkdir(systems[i].split("/")[-2])

# %%
#systems = glob.glob("*/")
#fnames = ["23_nptPR_confout.gro","charmm36-nov2018.ff","topol.top"]
#
#
#for i in range(len(systems)):
#    for replicaNum in range(10):
#        for fname in fnames:
#            copyStr = "cp -r ../4_Equilibration/alphafold_narval/systems/"+systems[i]+"23_nptPR/"+str(replicaNum)+"/"+fname+" ./"+systems[i]+str(replicaNum)
#            print(copyStr)
#            os.system(copyStr)
#
#

# %%
systems = glob.glob("*t5a*/")
fnames = glob.glob("productionFiles/*")

for i in range(len(systems)):
    for replicaNum in range(10):
        for fname in fnames:
        #for num in range(10):
            copyStr = "cp "+fname+" ./"+systems[i]+str(replicaNum)
            print(copyStr)
            os.system(copyStr)
            
            #rmStr = "rm ./"+systems[i]+str(replicaNum)+"/"+str(num)
            #print(rmStr)
            #os.system(rmStr)
# Out:
# cp productionFiles/do ./1_rht5a/0
# cp productionFiles/nptPR.mdp ./1_rht5a/0
# cp productionFiles/submit_array.sh ./1_rht5a/0
# cp productionFiles/do ./1_rht5a/1
# cp productionFiles/nptPR.mdp ./1_rht5a/1
# cp productionFiles/submit_array.sh ./1_rht5a/1
# cp productionFiles/do ./1_rht5a/2
# cp productionFiles/nptPR.mdp ./1_rht5a/2
# cp productionFiles/submit_array.sh ./1_rht5a/2
# cp productionFiles/do ./1_rht5a/3
# cp productionFiles/nptPR.mdp ./1_rht5a/3
# cp productionFiles/submit_array.sh ./1_rht5a/3
# cp productionFiles/do ./1_rht5a/4
# cp productionFiles/nptPR.mdp ./1_rht5a/4
# cp productionFiles/submit_array.sh ./1_rht5a/4
# cp productionFiles/do ./1_rht5a/5
# cp productionFiles/nptPR.mdp ./1_rht5a/5
# cp productionFiles/submit_array.sh ./1_rht5a/5
# cp productionFiles/do ./1_rht5a/6
# cp productionFiles/nptPR.mdp ./1_rht5a/6
# cp productionFiles/submit_array.sh ./1_rht5a/6
# cp productionFiles/do ./1_rht5a/7
# cp productionFiles/nptPR.mdp ./1_rht5a/7
# ...

# %%
fname
# Out:
# 'productionFiles/submit_array.sh'

# %%
systems
# Out:
# ['1_rht5a/', '2_t5a_wt/', '3_t5a_r332p/', 'productionFiles/']
