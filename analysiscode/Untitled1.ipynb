# %%
cs,n = [1], 1
def cnp1(n,c): return (4*n+2)*c/(n+2)
while cs[-1] < 5*10**9:cs.append(cnp1(n,cs[-1])); n+=1
print(cs)
# Out:
# [1, 2.0, 5.0, 14.0, 42.0, 132.0, 429.0, 1430.0, 4862.0, 16796.0, 58786.0, 208012.0, 742900.0, 2674440.0, 9694845.0, 35357670.0, 129644790.0, 477638700.0, 1767263190.0, 6564120420.0]
